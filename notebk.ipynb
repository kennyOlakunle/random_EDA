# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import plotly.express as px

# %%
#Load data

df_data = pd.read_csv('data_for_eda.csv')  

df_data.head()
# Out:
#      ID FirstName  LastName   Age  Gender      Occupation    Rating  \
# 0  8993   Michael     Jones  43.0    Male    Data Analyst  2.330366
# 1  2193   Michael  Martinez  53.0   Other    Data Analyst  2.067052
# 2  2198     Laura  Martinez  44.0    Male  Data Scientist  1.893609
# 3  2065      Emma     Jones  24.0  Female          Artist  1.000000
# 4  7726      Emma     Jones  48.0    Male          Lawyer  3.284565
#
#    Purchases  Experience        Income        Salary        Bonus
# 0          4         NaN  37957.829657  24678.301636  4045.322469
# 1          6        14.0  41720.614614  20474.990713  3050.257896
# 2          3        17.0  37709.965334  23076.131214  1393.256929
# 3          6         2.0   8393.574913  -3454.798899    29.640691
# 4          4        17.0  50107.709438  26536.818517  2703.234913

# %%
df_data.shape
# Out:
# (10100, 12)

# %%
df_data.dtypes
# Out:
# ID              int64
# FirstName      object
# LastName       object
# Age           float64
# Gender         object
# Occupation     object
# Rating        float64
# Purchases       int64
# Experience    float64
# Income        float64
# Salary        float64
# Bonus         float64
# dtype: object

# %% [markdown]
# ### General Information about dataset

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10100 entries, 0 to 10099
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   ID          10100 non-null  int64
#  1   FirstName   10100 non-null  object
#  2   LastName    10100 non-null  object
#  3   Age         9088 non-null   float64
#  4   Gender      10100 non-null  object
#  5   Occupation  10100 non-null  object
#  6   Rating      10100 non-null  float64
#  7   Purchases   10100 non-null  int64
#  8   Experience  9088 non-null   float64
#  9   Income      9095 non-null   float64
#  10  Salary      9093 non-null   float64
#  11  Bonus       9093 non-null   float64
# dtypes: float64(6), int64(2), object(4)
# memory usage: 947.0+ KB

# %% [markdown]
# ### Descriptive Statistics

# %%
df_data.describe()
# Out:
#                  ID          Age        Rating     Purchases   Experience  \
# count  10100.000000  9088.000000  10100.000000  10100.000000  9088.000000
# mean    5000.969406    39.511554      2.089470      5.002277    14.428917
# std     2886.175712     9.822653      0.770020      2.222876     4.973530
# min        0.000000     5.000000      1.000000      0.000000    -3.000000
# 25%     2503.750000    33.000000      1.457210      3.000000    11.000000
# 50%     5003.500000    39.000000      2.055191      5.000000    14.000000
# 75%     7496.250000    46.000000      2.635672      6.000000    18.000000
# max     9999.000000    79.000000      5.000000     20.000000    32.000000
#
#               Income        Salary        Bonus
# count    9095.000000   9093.000000  9093.000000
# mean    44461.299185  21462.985246  2154.554842
# std     40210.825866   8261.707429   965.541426
# min     -5394.028428  -9227.004705 -1673.243633
# 25%     32557.471452  16049.272884  1512.019074
# ...

# %%
#plot the df_data histogram but drop ID column

df_data.drop('ID', axis=1).hist(bins=30, figsize=(20,15))
plt.show()

# %%
for column in df_data.select_dtypes(include=['float64', 'int64']).columns:
    fig = px.histogram(df_data, x=column, title=f'Histogram of {column}')
    fig.show()
